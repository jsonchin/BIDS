# %%
from bs4 import BeautifulSoup
from IPython.display import Image
import dateutil.parser as dparser
import pandas as pd
import re
import time
import urllib.request

# %%
nsf_base = 'https://nsf.gov'
nsf_active_grants = 'https://nsf.gov/funding/pgm_list.jsp?sel_org=NSF&status=1&ord=date&org=NSF&page='

# %%
curr_page = 1
bad_headers = ["REVISIONS AND UPDATES", "EDUCATIONAL OPPORTUNITY", "RELATED URLS", "RELATED PROGRAMS"]
headlines = []
due_dates_start = []
due_dates_end = []
synopses = []
links = []

while True:
    links_page = urllib.request.urlopen(nsf_active_grants + str(curr_page))
    links_soup = BeautifulSoup(links_page, "html5lib")
    all_links = links_soup.find_all("a", class_="atemphover")
    print(curr_page)
    if all_links:
        for alink in all_links:
            try:
                error_code = 0
                full_link = nsf_base + alink.get("href")
                if full_link in links:
                    pass
                grant_url = urllib.request.urlopen(full_link)
                grant_soup = BeautifulSoup(grant_url, "html5lib") 

                # Headline
                temp = grant_soup.find("span", class_="pageheadsubline")
                headline = temp.find_next_sibling("h2").text.partition("\n")[0]
                headlines.append(headline)
                error_code = 1

                # Date
                try:
                    temp = grant_soup.find("strong", text=re.compile("Full Proposal")).parent.text
                    temp_split = temp.split()
                    if "Window" in temp_split:
                        start_end = " ".join(temp_split).split("-")
                        start = dparser.parse(start_end[0], fuzzy=True).strftime('%Y-%m-%d')
                        end = dparser.parse(start_end[1], fuzzy=True).strftime('%Y-%m-%d')
                        due_dates_start.append(start)
                        due_dates_end.append(end)
                    else:
                        due_date = dparser.parse(temp, fuzzy=True).strftime('%Y-%m-%d')
                        due_dates_start.append("None")
                        due_dates_end.append(due_date)
                except:
                    try:
                        temp = grant_soup.find("strong", text=re.compile("DUE DATES"))
                        date = temp.parent.next_sibling.next_sibling.next_sibling.strip()
                        if not date:
                            raise ValueError("Date empty")
                        due_dates_start.append("None")
                        due_dates_end.append(due_date)
                    except:
                        print("Not listed")
                        print(full_link)
                        due_dates_start.append("Not listed")
                        due_dates_end.append("Not listed")
                        
                # Synopsis
                error_code = 2
                temp = grant_soup.find("strong", text=re.compile("SYNOPSIS"))
                synopsis = temp.parent.find_next_sibling('p').text
                for header in bad_headers:
                    if header in synopsis:
                        synopsis = temp.next_sibling.next_sibling.next_sibling.strip()
                synopses.append(synopsis)
                
                links.append(full_link)
                time.sleep(0.01)
            except:
                if error_code == 0:
                    print("Error code: 0")
                    print(nsf_base + alink.get("href"))
                elif error_code == 1:
                    print("Error code: 1")
                    print(nsf_base + alink.get("href"))
                    headlines.pop()
                elif error_code == 2:
                    print("Error code: 2")
                    print(nsf_base + alink.get("href"))
                    headlines.pop()
                    due_dates.pop()
    else:
        break
    curr_page += 1
# Out:
# 1
# 2
# 3
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=5483&org=NSF&sel_org=NSF&from=fund
# 4
# 5
# 6
# 7
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=5483&org=NSF&sel_org=NSF&from=fund
# 8
# 9
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=5483&org=NSF&sel_org=NSF&from=fund
# 10
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=5483&org=NSF&sel_org=NSF&from=fund
# 11
# 12
# 13
# 14
# 15
# 16
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=5483&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=12756&org=NSF&sel_org=NSF&from=fund
# 17
# 18
# 19
# 20
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=11686&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=505076&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=5521&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=11692&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=501030&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=6668&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=505354&org=NSF&sel_org=NSF&from=fund
# 21
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=11699&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=505357&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=11701&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=505350&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=505385&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=505291&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=12789&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=505309&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=6186&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=503341&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=5518&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=13689&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=13690&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=12808&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=505409&org=NSF&sel_org=NSF&from=fund
# 22
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=5319&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=13684&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=12807&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=11725&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=5359&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=5665&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=5605&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=13524&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=504848&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=12727&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=12728&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=5338&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=11691&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=13691&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=505314&org=NSF&sel_org=NSF&from=fund
# 23
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=12741&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=5464&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=504720&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=504793&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=505125&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=5474&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=505157&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=13424&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=503222&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=13425&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=13426&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=505151&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=505185&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=505264&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=504748&org=NSF&sel_org=NSF&from=fund
# 24
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=503210&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=504951&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=504743&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=504816&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=5147&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=505203&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=504840&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=5503&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=504773&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=505277&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=500044&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=503172&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=505287&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=504829&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=504991&org=NSF&sel_org=NSF&from=fund
# 25
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=504984&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=504776&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=6192&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=505073&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=505281&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=503446&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=503223&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=503429&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=503429&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=505263&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=505263&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=503169&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=504842&org=NSF&sel_org=NSF&from=fund
# 26
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=500085&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=504754&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=505256&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=504882&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=5502&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=505271&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=13516&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=5506&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=505127&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=503148&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=505229&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=505082&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=505169&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=505132&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=503382&org=NSF&sel_org=NSF&from=fund
# 27
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=505105&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=5300&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=505103&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=7671&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=505270&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=13646&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=505078&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=504938&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=505171&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=505133&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=5295&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=13654&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=5302&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=504874&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=504928&org=NSF&sel_org=NSF&from=fund
# 28
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=505149&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=505015&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=503259&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=505317&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=504949&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=5291&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=8170&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=505258&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=505319&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=505047&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=505310&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=505085&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=505298&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=503512&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=505301&org=NSF&sel_org=NSF&from=fund
# 29
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=5750&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=5327&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=13460&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=504726&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=504790&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=504708&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=5439&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=5305&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=503613&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=5338&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=505316&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=5473&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=504995&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=505170&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=505265&org=NSF&sel_org=NSF&from=fund
# 30
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=505348&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=505240&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=505176&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=504834&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=504996&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=505233&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=505362&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=505364&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=504739&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=505311&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=13673&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=504843&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=505069&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=6682&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=504828&org=NSF&sel_org=NSF&from=fund
# 31
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=505136&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=505035&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=505037&org=NSF&sel_org=NSF&from=fund
# Error code: 0
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=12769&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=7671&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=7671&org=NSF&sel_org=NSF&from=fund
# 32
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=504773&org=NSF&sel_org=NSF&from=fund
# 33
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=5750&org=NSF&sel_org=NSF&from=fund
# Not listed
# https://nsf.gov/funding/pgm_summ.jsp?pims_id=6682&org=NSF&sel_org=NSF&from=fund
# 34

# %%
df = pd.DataFrame()

# %%
df['Headline'] = headlines
df['Due Date Start'] = due_dates_start
df['Due Date End'] = due_dates_end
df['Description'] = synopses
df['Link'] = links

# %%
df[155:165]
# Out:
#                                               Headline Due Date Start  \
# 155                        Combustion and Fire Systems     2017-10-01
# 156          Disability and Rehabilitation Engineering     2017-10-01
# 157                          Energy for Sustainability     2017-10-01
# 158                  Engineering of Biomedical Systems     2017-10-01
# 159                          Environmental Engineering     2017-10-01
# 160                       Environmental Sustainability     2017-10-01
# 161                                     Fluid Dynamics     2017-10-01
# 162                                    Nano-Biosensing     2017-10-01
# 163  NSF/DOE Partnership in Basic Plasma Science an...           None
# 164               Particulate and Multiphase Processes     2017-10-01
#
#     Due Date End                                        Description  \
# 155   2017-10-20  The Combustion and Fire Systems program is par...
# 156   2017-10-20  The Disability and Rehabilitation Engineering ...
# 157   2017-10-20  The Energy for Sustainability program is part ...
# 158   2017-10-20  The Engineering of Biomedical Systems program ...
# 159   2017-10-20  The Environmental Engineering program is part ...
# 160   2017-10-20  The Environmental Sustainability program is pa...
# 161   2017-10-20  The Fluid Dynamics program is part of the Tran...
# 162   2017-10-20  The Nano-Biosensing program is part of the Eng...
# 163   2017-10-20  Plasma Physics is a study of matter and physic...
# 164   2017-10-20  The Particulate and Multiphase Processes progr...
#
#                                                   Link
# 155  https://nsf.gov/funding/pgm_summ.jsp?pims_id=5...
# 156  https://nsf.gov/funding/pgm_summ.jsp?pims_id=5...
# 157  https://nsf.gov/funding/pgm_summ.jsp?pims_id=5...
# 158  https://nsf.gov/funding/pgm_summ.jsp?pims_id=5...
# 159  https://nsf.gov/funding/pgm_summ.jsp?pims_id=5...
# 160  https://nsf.gov/funding/pgm_summ.jsp?pims_id=5...
# 161  https://nsf.gov/funding/pgm_summ.jsp?pims_id=1...
# 162  https://nsf.gov/funding/pgm_summ.jsp?pims_id=5...
# 163  https://nsf.gov/funding/pgm_summ.jsp?pims_id=5...
# 164  https://nsf.gov/funding/pgm_summ.jsp?pims_id=5...

# %%
df.to_csv("nsf_grants.csv", sep="~", index=False)
